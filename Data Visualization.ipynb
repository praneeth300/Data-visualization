# %% [markdown]
# # Visualizing statistical relationships
#
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
#
# ### 1. Numerical Data Ploting
# - relplot()
# - scatterplot()
# - lineplot()
#
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...
#
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()
#
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()
#
# ### 5. Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
#Import the libraries
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips=pd.read_csv(r"C:\Users\Praneeth\Downloads\archive\tips.csv")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Numerical data plotting
sns.relplot(x='total_bill',y='tip',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='time',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='day',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='sex',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',hue='size',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',size='sex',data=tips)

# %%
from numpy.random import randn

# %%
df=pd.DataFrame(dict(time=np.arange(100),value=randn(100).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0  0.804398
# 1     1  0.074160
# 2     2  0.419840
# 3     3  0.921219
# 4     4  1.875183

# %%
sns.relplot(x='time',y='value',data=df,kind='line',sort=True)

# %%
df1=pd.DataFrame(randn(100,2),columns=['P1','P2'])

# %%
df1.head()
# Out:
#          P1        P2
# 0 -0.205890  2.039049
# 1 -1.113591 -0.877633
# 2 -0.087809 -0.993227
# 3  0.476935  0.849318
# 4  0.339630 -0.181435

# %%
sns.relplot(x='P1',y='P2',data=df1,kind='line',sort=True)

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',hue='region',size='event')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',hue='region',style='event')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',hue='region',style='event',markers=True,dashes=False)

# %%
df2=pd.DataFrame(dict(time=pd.date_range('1-1-1999',periods=100),value=randn(100).cumsum()))

# %%
df2.head()
# Out:
#         time     value
# 0 1999-01-01 -1.571330
# 1 1999-01-02 -1.712079
# 2 1999-01-03 -2.554593
# 3 1999-01-04 -2.090980
# 4 1999-01-05 -2.011511

# %%
g=sns.relplot(x='time',y='value',kind='line',data=df2)
g.fig.autofmt_xdate()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',data=tips,col='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col='day',col_wrap=2,height=4)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col='time')

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='smoker',size='size',style='time')

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=iris)

# %%
sns.scatterplot(x='sepal_width',y='petal_width',data=iris,hue='species')

# %% [markdown]
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='sex',y='tip',hue='smoker',data=tips)

# %%
sns.catplot(x='day',y='tip',hue='sex',data=tips)

# %%
sns.catplot(y='day',x='total_bill',data=tips)

# %%
sns.catplot(x='time',y='total_bill',data=tips,jitter=False)

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='swarm',hue='smoker')

# %%
sns.catplot(x='day',y='total_bill',hue='smoker',kind='box',data=tips)

# %%
sns.boxplot(x='sex',y='tip',data=tips,hue='smoker',order=['Male','Female'])

# %%
sns.catplot(x='day',y='tip',data=tips,hue='sex',kind='box',dodge=False)

# %%
dia=sns.load_dataset('diamonds')

# %%
dia.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dia['color'].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
sns.catplot(x='color',y='price',data=dia.sort_values('color'),kind='boxen')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day',y='total_bill',kind='boxen',data=tips)

# %%
sns.catplot(x='day',y='total_bill',kind='violin',hue='sex',data=tips,split=True)

# %%
tit=sns.load_dataset('titanic')

# %%
tit.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='deck',kind='count',hue='pclass',data=tit)

# %% [markdown]
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()

# %%
x=randn(100)

# %%
sns.distplot(x,kde=True,hist=True,bins=50)

# %%
df3=pd.DataFrame(dict(time=pd.date_range('17-10-2020',periods=500),value=randn(500).cumsum()))

# %%
df3.head()
# Out:
#         time     value
# 0 2020-10-17 -0.083195
# 1 2020-10-18 -1.072470
# 2 2020-10-19 -0.890451
# 3 2020-10-20 -0.125237
# 4 2020-10-21 -1.000735

# %%
sns.distplot(df3['value'],hist=True,kde=True,bins=30,)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x=tips['total_bill']
y=tips['tip']

# %%
sns.jointplot(x=x,y=y)

# %%
sns.set()
sns.jointplot(x=x,y=y,kind='hex')

# %%
sns.set()
sns.jointplot(x,y,kind='kde')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(data=iris,hue='species')

# %% [markdown]
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
df4=sns.load_dataset('anscombe')

# %%
df4.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sns.regplot(x='x',y='y',data=df4)

# %%
f,ax=plt.subplots(figsize=(8,4))
sns.regplot(x='total_bill',y='tip',data=tips,ax=ax)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',col_wrap=3,height=4,hue='smoker')

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}
